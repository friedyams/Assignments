# %%
import pandas as pd
import seaborn
import matplotlib as mpl
import numpy as np
import re

# %%
housing_df = pd.read_excel("Median_Housing_Prices.xls")
housing_df.filter(items=['CA', 'Los Angeles', 'San Francisco'])
# Out:
#                 CA    Los Angeles  San Francisco
# 0    194952.000000  215337.926006         287499
# 1    196273.000000  208399.117906         300877
# 2    194856.000000  208134.862749         290151
# 3    196111.000000  219003.989632         288725
# 4    195281.000000  209065.024168         282626
# 5    194410.000000  210605.895742         305738
# 6    193088.000000  225250.714143         296195
# 7    192180.000000  213478.489676         284523
# 8    189979.000000  211552.002447         278301
# 9    187630.000000  207801.384318         272500
# 10   192020.000000  202716.814957         281249
# 11   190375.000000  212855.455029         272777
# 12   192054.000000  197706.413753         270161
# 13   194806.000000  199157.204997         270714
# 14   202666.000000  207939.683633         268055
# 15   207718.000000  213442.452562         279941
# 16   211001.000000  218891.850428         280319
# 17   206722.000000  224055.042847         291666
# ...
